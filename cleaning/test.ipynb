# %%
import pandas as pd
df = pd.read_csv('cleaned_smartwatch.csv')
df.isnull().sum()
# Out:
# User ID                   201
# Heart Rate (BPM)            0
# Blood Oxygen Level (%)      0
# Step Count                  0
# Sleep Duration (hours)      0
# Activity Level              0
# Stress Level                0
# dtype: int64
